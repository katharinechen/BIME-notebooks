# %% [markdown]
# ## Exploration of AMB dataset
#
# ### Questions
#
# - What does each row represent? A Dx, a Rx?
# - How many unique patients under `P32c` and `P33`
# - How many diagnoses under `P32c` and `P33`

# %% [markdown]
# ## Data cleaning
#
# We begin by creating a new CSV file that will only include `P32c` and `P33` HCGs

# %%
import csv
import pandas as pd

# %% [markdown]
# ## We filter the data and save it in a new file

# %%
SOURCE = 'AMB_ALL.tsv'
TARGET = 'SELECTED_HCG.tsv'

ALLOWED_HCG = ['p32c', 'p33']
HEADERS = ['year', 'quarter', 'patid', 'gender', 'agegrp', 'race', 'ethnicity', 'language', 'metro', 'paid', 'patpaid', 'payer', 'pos', 'urban', 'dx1', 'px1', 'hcg']

# %%
# %time
# with open(SOURCE, 'rt') as f, open(TARGET, 'wt') as g:
#     csvreader = csv.DictReader(f, fieldnames=HEADERS, delimiter="\t", )
#     csvwriter = csv.DictWriter(g, fieldnames=HEADERS, delimiter="\t")
#     csvwriter.writerow(csvreader.next())
#     for row in csvreader:
#         if row['hcg'].lower() in ALLOWED_HCG:
#             csvwriter.writerow(row)
# Out:
# CPU times: user 3 µs, sys: 4 µs, total: 7 µs
# Wall time: 7.15 µs

# %%
x = pd.read_csv(TARGET, delimiter="\t")

# %% [markdown]
# ## How many unique patients diagnosed under `P32c` and `P33` ?

# %%
# %time total_number_of_unique_patients = len(x['patid'].unique())
print "There are %d unique patients" % total_number_of_unique_patients
# Out:
# CPU times: user 2.21 s, sys: 86.3 ms, total: 2.3 s
# Wall time: 2.31 s
# There are 2276316 unique patients

# %% [markdown]
# ## How many unique Dx under `P32c` and `P33` ?

# %%
# %time total_number_of_unique_dx = len(x['dx1'].unique())
total_number_of_dx = len(x)
print "There are %d unique dx" % total_number_of_unique_dx
# Out:
# CPU times: user 501 ms, sys: 34.6 ms, total: 535 ms
# Wall time: 539 ms
# There are 9837 unique dx

# %%
print "Each patient is has on average %.2f diagnoses" % (len(x) / float(total_number_of_unique_patients))
# Out:
# Each patient is has on average 3.43 diagnoses

# %% [markdown]
# ## Read ICD2Module

# %%
MODULES_FILE = 'Bright.md ICD-9 codes.xlsx - ICD codes.tsv'
modules = pd.read_csv(MODULES_FILE, delimiter="\t")

# %%
icd9 = [i for i in modules['ICD-9'].dropna().unique()]
print "Smartexam supports %d ICD9 diagnoses" % len(icd9)
# Out:
# Smartexam supports 60 ICD9 diagnoses

# %%
unique_icd9_supercategories = set([i.split('.')[0] for i in icd9])

# %% [markdown]
# ### We strip `dx1` and save it back

# %%
x['dx1'] = x['dx1'].str.strip()
# x.to_csv(TARGET, sep="\t")

# %%
data_supercategories = set()
for i in set(x['dx1']):
    data_supercategories.add(i[:3])

# %%
rows_supported_by_brightmd = data_supercategories.intersection(unique_icd9_supercategories)
total_number_of_rows = len(x)

# %% [markdown]
# ## How many total diagnoses are supported by Brightmd's modules?

# %%
print "Smartexam supports %d out of %d total diagnoses (%.2f%%)" % (len(rows_supported_by_brightmd),
                                                                  total_number_of_rows,
                                                                  (100*len(rows_supported_by_brightmd)/float(total_number_of_rows)))
# Out:
# Smartexam supports 36 out of 7803527 total diagnoses (0.00%)

# %%
print "%.2f%%" % (100*len(icd9)/float(len(x['dx1'].unique())))
# Out:
# 0.61%

# %%
y = pd.value_counts(x['dx1']).head(50)
y
# Out:
# 4019     207540
# 25000    200812
# 4659     173543
# 4011     171634
# 42731    122418
# 462      116306
# 7862     100743
# 7242      98311
# 2724      86240
# 5990      84871
# 4619      81053
# 3829      76761
# 7295      74826
# 78079     73627
# 30000     72955
# 71946     69988
# 4660      66367
# 311       66104
# 2449      63644
# 49390     62332
# 78900     61512
# 7245      55613
# 6929      53724
# 25002     52962
# 31401     52740
# 7881      47808
# 7840      47100
# 4779      45622
# 71941     45114
# 78650     43921
# 7821      43560
# 32723     42782
# 53081     42671
# 486       42446
# 496       42372
# 7231      40769
# V700      39519
# 4739      38144
# V5883     37923
# 490       36982
# 78791     36401
# 7804      36344
# 7244      32887
# V5861     32710
# 7291      32299
# 7823      31887
# 71945     31165
# 0340      30105
# 78060     30068
# 31400     29624
# Name: dx1, dtype: int64

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.hipaaspace.com/Medical_Billing/Crosswalk.Services/ICD-9.to.ICD-10.Mapping/%s'
stats = []
for k in y.keys():
    r = requests.get(url % k)
    soup = BeautifulSoup(r.text)
    tables = soup.find_all("table")
    rows = tables[1].findChildren('tr')
    td = rows[3].findChildren('td')
    stats.append({'total': y[k], 'description': td[0].text.replace('(Diagnosis) - ', '').strip()})

stats = pd.DataFrame(stats)
stats.head(50)
# Out:
#                                           description   total
# 0   4019 Hypertension NOS (Unspecified essential h...  207540
# 1   25000 DMII wo cmp nt st uncntr (Diabetes melli...  200812
# 2   4659 Acute uri NOS (Acute upper respiratory in...  173543
# 3   4011 Benign hypertension (Benign essential hyp...  171634
# 4                           42731 Atrial fibrillation  122418
# 5                               462 Acute pharyngitis  116306
# 6                                          7862 Cough  100743
# 7                                        7242 Lumbago   98311
# 8   2724 Hyperlipidemia NEC/NOS (Other and unspeci...   86240
# 9   5990 Urin tract infection NOS (Urinary tract i...   84871
# 10  4619 Acute sinusitis NOS (Acute sinusitis, uns...   81053
# 11   3829 Otitis media NOS (Unspecified otitis media)   76761
# 12                                  7295 Pain in limb   74826
# 13  78079 Malaise and fatigue NEC (Other malaise a...   73627
# 14  30000 Anxiety state NOS (Anxiety state, unspec...   72955
# 15  71946 Joint pain-l/leg (Pain in joint, lower leg)   69988
# 16                              4660 Acute bronchitis   66367
# 17  311 Depressive disorder NEC (Depressive disord...   66104
# 18  2449 Hypothyroidism NOS (Unspecified acquired ...   63644
# 19  49390 Asthma NOS (Asthma, unspecified type, un...   62332
# 20  78900 Abdmnal pain unspcf site (Abdominal pain...   61512
# 21          7245 Backache NOS (Backache, unspecified)   55613
# 22  6929 Dermatitis NOS (Contact dermatitis and ot...   53724
# 23  25002 DMII wo cmp uncntrld (Diabetes mellitus ...   52962
# 24  31401 Attn deficit w hyperact (Attention defic...   52740
# 25                                       7881 Dysuria   47808
# 26                                      7840 Headache   47100
# 27  4779 Allergic rhinitis NOS (Allergic rhinitis,...   45622
# 28  71941 Joint pain-shlder (Pain in joint, should...   45114
# 29     78650 Chest pain NOS (Chest pain, unspecified)   43921
# 30  7821 Nonspecif skin erupt NEC (Rash and other ...   43560
# 31  32723 Obstructive sleep apnea (Obstructive sle...   42782
# 32                            53081 Esophageal reflux   42671
# 33  486 Pneumonia, organism NOS (Pneumonia, organi...   42446
# 34  496 Chr airway obstruct NEC (Chronic airway ob...   42372
# 35                                   7231 Cervicalgia   40769
# 36  V700 Routine medical exam (Routine general med...   39519
# 37  4739 Chronic sinusitis NOS (Unspecified sinusi...   38144
# 38  V5883 Therapeutic drug monitor (Encounter for ...   37923
# 39  490 Bronchitis NOS (Bronchitis, not specified ...   36982
# 40                                     78791 Diarrhea   36401
# 41                       7804 Dizziness and giddiness   36344
# 42  7244 Lumbosacral neuritis NOS (Thoracic or lum...   32887
# 43  V5861 Long-term use anticoagul (Long-term (cur...   32710
# 44  7291 Myalgia and myositis NOS (Myalgia and myo...   32299
# 45                                         7823 Edema   31887
# 46  71945 Joint pain-pelvis (Pain in joint, pelvic...   31165
# 47  0340 Strep sore throat (Streptococcal sore thr...   30105
# 48               78060 Fever NOS (Fever, unspecified)   30068
# 49  31400 Attn defic nonhyperact (Attention defici...   29624

# %%
100* (1 - len(data_supercategories.difference(unique_icd9_supercategories))/float(len(data_supercategories)))
# Out:
# 3.5019455252918275

# %%
sorted(data_supercategories)
# Out:
# ['*NU',
#  '000',
#  '002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '011',
#  '012',
#  '013',
#  '014',
#  '015',
#  '016',
#  '017',
#  '018',
#  '020',
#  '021',
#  '023',
#  '024',
#  '025',
#  '026',
#  '027',
#  '030',
#  '031',
#  '032',
#  '033',
#  '034',
#  '035',
#  '036',
#  '037',
#  '038',
#  '039',
#  '040',
#  '041',
#  '042',
#  '045',
#  '046',
#  '047',
#  '048',
#  '049',
#  '050',
#  '051',
#  '052',
#  '053',
#  '054',
#  '055',
#  '056',
#  '057',
#  '058',
#  '061',
#  '063',
#  '065',
#  '066',
#  '070',
#  '072',
#  '073',
#  '074',
#  '075',
#  '076',
#  '077',
#  '078',
#  '079',
#  '081',
#  '082',
#  '083',
#  '084',
#  '085',
#  '086',
#  '087',
#  '088',
#  '090',
#  '091',
#  '092',
#  '093',
#  '094',
#  '095',
#  '096',
#  '097',
#  '098',
#  '099',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '110',
#  '111',
#  '112',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '169',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '179',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '190',
#  '191',
#  '192',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '199',
#  '200',
#  '201',
#  '202',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '210',
#  '211',
#  '212',
#  '213',
#  '214',
#  '215',
#  '216',
#  '217',
#  '218',
#  '219',
#  '220',
#  '221',
#  '222',
#  '223',
#  '224',
#  '225',
#  '226',
#  '227',
#  '228',
#  '229',
#  '230',
#  '231',
#  '232',
#  '233',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244',
#  '245',
#  '246',
#  '249',
#  '250',
#  '251',
#  '252',
#  '253',
#  '254',
#  '255',
#  '256',
#  '257',
#  '258',
#  '259',
#  '260',
#  '261',
#  '262',
#  '263',
#  '264',
#  '265',
#  '266',
#  '267',
#  '268',
#  '269',
#  '270',
#  '271',
#  '272',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '280',
#  '281',
#  '282',
#  '283',
#  '284',
#  '285',
#  '286',
#  '287',
#  '288',
#  '289',
#  '290',
#  '291',
#  '292',
#  '293',
#  '294',
#  '295',
#  '296',
#  '297',
#  '298',
#  '299',
#  '300',
#  '301',
#  '302',
#  '303',
#  '304',
#  '305',
#  '306',
#  '307',
#  '308',
#  '309',
#  '310',
#  '311',
#  '312',
#  '313',
#  '314',
#  '315',
#  '316',
#  '317',
#  '318',
#  '319',
#  '320',
#  '321',
#  '322',
#  '323',
#  '324',
#  '325',
#  '326',
#  '327',
#  '330',
#  '331',
#  '332',
#  '333',
#  '334',
#  '335',
#  '336',
#  '337',
#  '338',
#  '339',
#  '340',
#  '341',
#  '342',
#  '343',
#  '344',
#  '345',
#  '346',
#  '347',
#  '348',
#  '349',
#  '350',
#  '351',
#  '352',
#  '353',
#  '354',
#  '355',
#  '356',
#  '357',
#  '358',
#  '359',
#  '360',
#  '361',
#  '362',
#  '363',
#  '364',
#  '365',
#  '366',
#  '367',
#  '368',
#  '369',
#  '370',
#  '371',
#  '372',
#  '373',
#  '374',
#  '375',
#  '376',
#  '377',
#  '378',
#  '379',
#  '380',
#  '381',
#  '382',
#  '383',
#  '384',
#  '385',
#  '386',
#  '387',
#  '388',
#  '389',
#  '390',
#  '391',
#  '392',
#  '393',
#  '394',
#  '395',
#  '396',
#  '397',
#  '398',
#  '401',
#  '402',
#  '403',
#  '404',
#  '405',
#  '410',
#  '411',
#  '412',
#  '413',
#  '414',
#  '415',
#  '416',
#  '417',
#  '420',
#  '421',
#  '422',
#  '423',
#  '424',
#  '425',
#  '426',
#  '427',
#  '428',
#  '429',
#  '430',
#  '431',
#  '432',
#  '433',
#  '434',
#  '435',
#  '436',
#  '437',
#  '438',
#  '440',
#  '441',
#  '442',
#  '443',
#  '444',
#  '445',
#  '446',
#  '447',
#  '448',
#  '449',
#  '451',
#  '452',
#  '453',
#  '454',
#  '455',
#  '456',
#  '457',
#  '458',
#  '459',
#  '460',
#  '461',
#  '462',
#  '463',
#  '464',
#  '465',
#  '466',
#  '470',
#  '471',
#  '472',
#  '473',
#  '474',
#  '475',
#  '476',
#  '477',
#  '478',
#  '480',
#  '481',
#  '482',
#  '483',
#  '484',
#  '485',
#  '486',
#  '487',
#  '488',
#  '490',
#  '491',
#  '492',
#  '493',
#  '494',
#  '495',
#  '496',
#  '501',
#  '502',
#  '503',
#  '504',
#  '505',
#  '506',
#  '507',
#  '508',
#  '510',
#  '511',
#  '512',
#  '513',
#  '514',
#  '515',
#  '516',
#  '517',
#  '518',
#  '519',
#  '520',
#  '521',
#  '522',
#  '523',
#  '524',
#  '525',
#  '526',
#  '527',
#  '528',
#  '529',
#  '530',
#  '531',
#  '532',
#  '533',
#  '534',
#  '535',
#  '536',
#  '537',
#  '538',
#  '539',
#  '540',
#  '541',
#  '542',
#  '543',
#  '550',
#  '551',
#  '552',
#  '553',
#  '555',
#  '556',
#  '557',
#  '558',
#  '560',
#  '562',
#  '564',
#  '565',
#  '566',
#  '567',
#  '568',
#  '569',
#  '570',
#  '571',
#  '572',
#  '573',
#  '574',
#  '575',
#  '576',
#  '577',
#  '578',
#  '579',
#  '580',
#  '581',
#  '582',
#  '583',
#  '584',
#  '585',
#  '586',
#  '587',
#  '588',
#  '589',
#  '590',
#  '591',
#  '592',
#  '593',
#  '594',
#  '595',
#  '596',
#  '597',
#  '598',
#  '599',
#  '600',
#  '601',
#  '602',
#  '603',
#  '604',
#  '605',
#  '606',
#  '607',
#  '608',
#  '610',
#  '611',
#  '612',
#  '614',
#  '615',
#  '616',
#  '617',
#  '618',
#  '619',
#  '620',
#  '621',
#  '622',
#  '623',
#  '624',
#  '625',
#  '626',
#  '627',
#  '628',
#  '629',
#  '630',
#  '631',
#  '632',
#  '633',
#  '634',
#  '635',
#  '637',
#  '638',
#  '639',
#  '640',
#  '641',
#  '642',
#  '643',
#  '644',
#  '645',
#  '646',
#  '647',
#  '648',
#  '649',
#  '650',
#  '651',
#  '652',
#  '653',
#  '654',
#  '655',
#  '656',
#  '657',
#  '658',
#  '659',
#  '660',
#  '661',
#  '662',
#  '663',
#  '664',
#  '665',
#  '666',
#  '667',
#  '668',
#  '669',
#  '670',
#  '671',
#  '672',
#  '673',
#  '674',
#  '675',
#  '676',
#  '679',
#  '680',
#  '681',
#  '682',
#  '683',
#  '684',
#  '685',
#  '686',
#  '690',
#  '691',
#  '692',
#  '693',
#  '694',
#  '695',
#  '696',
#  '697',
#  '698',
#  '700',
#  '701',
#  '702',
#  '703',
#  '704',
#  '705',
#  '706',
#  '707',
#  '708',
#  '709',
#  '710',
#  '711',
#  '712',
#  '713',
#  '714',
#  '715',
#  '716',
#  '717',
#  '718',
#  '719',
#  '720',
#  '721',
#  '722',
#  '723',
#  '724',
#  '725',
#  '726',
#  '727',
#  '728',
#  '729',
#  '730',
#  '731',
#  '732',
#  '733',
#  '734',
#  '735',
#  '736',
#  '737',
#  '738',
#  '739',
#  '740',
#  '741',
#  '742',
#  '743',
#  '744',
#  '745',
#  '746',
#  '747',
#  '748',
#  '749',
#  '750',
#  '751',
#  '752',
#  '753',
#  '754',
#  '755',
#  '756',
#  '757',
#  '758',
#  '759',
#  '760',
#  '761',
#  '762',
#  '763',
#  '764',
#  '765',
#  '766',
#  '767',
#  '768',
#  '769',
#  '770',
#  '771',
#  '772',
#  '773',
#  '774',
#  '775',
#  '776',
#  '777',
#  '778',
#  '779',
#  '780',
#  '781',
#  '782',
#  '783',
#  '784',
#  '785',
#  '786',
#  '787',
#  '788',
#  '789',
#  '790',
#  '791',
#  '792',
#  '793',
#  '794',
#  '795',
#  '796',
#  '797',
#  '798',
#  '799',
#  '800',
#  '801',
#  '802',
#  '803',
#  '804',
#  '805',
#  '806',
#  '807',
#  '808',
#  '809',
#  '810',
#  '811',
#  '812',
#  '813',
#  '814',
#  '815',
#  '816',
#  '817',
#  '818',
#  '819',
#  '820',
#  '821',
#  '822',
#  '823',
#  '824',
#  '825',
#  '826',
#  '827',
#  '828',
#  '829',
#  '830',
#  '831',
#  '832',
#  '833',
#  '834',
#  '835',
#  '836',
#  '837',
#  '838',
#  '839',
#  '840',
#  '841',
#  '842',
#  '843',
#  '844',
#  '845',
#  '846',
#  '847',
#  '848',
#  '850',
#  '851',
#  '852',
#  '853',
#  '854',
#  '860',
#  '861',
#  '862',
#  '863',
#  '864',
#  '865',
#  '866',
#  '867',
#  '868',
#  '869',
#  '870',
#  '871',
#  '872',
#  '873',
#  '874',
#  '875',
#  '876',
#  '877',
#  '878',
#  '879',
#  '880',
#  '881',
#  '882',
#  '883',
#  '884',
#  '885',
#  '886',
#  '887',
#  '890',
#  '891',
#  '892',
#  '893',
#  '894',
#  '895',
#  '896',
#  '897',
#  '900',
#  '901',
#  '902',
#  '903',
#  '904',
#  '905',
#  '906',
#  '907',
#  '908',
#  '909',
#  '910',
#  '911',
#  '912',
#  '913',
#  '914',
#  '915',
#  '916',
#  '917',
#  '918',
#  '919',
#  '920',
#  '921',
#  '922',
#  '923',
#  '924',
#  '925',
#  '926',
#  '927',
#  '928',
#  '929',
#  '930',
#  '931',
#  '932',
#  '933',
#  '934',
#  '935',
#  '936',
#  '937',
#  '938',
#  '939',
#  '940',
#  '941',
#  '942',
#  '943',
#  '944',
#  '945',
#  '946',
#  '947',
#  '948',
#  '949',
#  '950',
#  '951',
#  '952',
#  '953',
#  '954',
#  '955',
#  '956',
#  '957',
#  '958',
#  '959',
#  '960',
#  '961',
#  '962',
#  '963',
#  '964',
#  '965',
#  '966',
#  '967',
#  '968',
#  '969',
#  '971',
#  '972',
#  '973',
#  '974',
#  '975',
#  '976',
#  '977',
#  '978',
#  '979',
#  '980',
#  '981',
#  '982',
#  '983',
#  '984',
#  '985',
#  '986',
#  '987',
#  '988',
#  '989',
#  '990',
#  '991',
#  '992',
#  '993',
#  '994',
#  '995',
#  '996',
#  '997',
#  '998',
#  '999',
#  'D99',
#  'E00',
#  'E11',
#  'E81',
#  'E82',
#  'E84',
#  'E86',
#  'E88',
#  'E90',
#  'E91',
#  'E92',
#  'E93',
#  'E94',
#  'E95',
#  'E96',
#  'E98',
#  'E99',
#  'ICR',
#  'L30',
#  'L70',
#  'NON',
#  'ULI',
#  'V01',
#  'V02',
#  'V03',
#  'V04',
#  'V05',
#  'V06',
#  'V07',
#  'V08',
#  'V09',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'V31',
#  'V33',
#  'V34',
#  'V39',
#  'V40',
#  'V41',
#  'V42',
#  'V43',
#  'V44',
#  'V45',
#  'V46',
#  'V47',
#  'V48',
#  'V49',
#  'V50',
#  'V51',
#  'V52',
#  'V53',
#  'V54',
#  'V55',
#  'V56',
#  'V57',
#  'V58',
#  'V59',
#  'V60',
#  'V61',
#  'V62',
#  'V64',
#  'V65',
#  'V66',
#  ...]

# %%
len(data_supercategories)
# Out:
# 1028

# %%
len(unique_icd9_supercategories.difference(data_supercategories))
# Out:
# 8

# %%
len(unique_icd9_supercategories)
# Out:
# 44
